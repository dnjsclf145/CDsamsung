# %% [markdown]
# **각 단원 실습 자료에서 ctrl + f 를 활용하여 내용을 찾아 볼수 있습니다.**

# %% [markdown]
# ### 02 파이썬 기초
# - 변수 할당
# - 기본 자료형
#     - int, float
#     - str
#         - format(포맷팅)
#     - bool
#     - 연산자, 비교연산자
#     - 형변환
# - 함수 활용
#     - 파라미터
#     - return
# - 클래스 활용
#     - 클래스와 인스턴스
#     - 셀프 변수
#     - 클래스에서 함수
# - 조건문
#     - if in
#     - else
#     - elif
# - 반복문
#     - for in
#     - continue
#     - break
# - 데이터구조
#     - 각 데이터구조 생성과 시퀀스 연산자 활용
#     - list 리스트
#         - append, expend, sort, reverse
#         - 가변 구조
#     - 튜플
#         - 불변 구조
#     - 문자열 sts
#         - 불변 구조
#         - split, strip, replace
#     - 딕셔너리 dict
#         - 해쉬셋 set
#         - 계층 구조
#     - 배열 numpy
#         - 외부 모듈
#         - aixs(축) 와 shape(형상)
#     - 테이블구조 DataFrame
#         - 외부 모듈 (pandas)

# %% [markdown]
# ### 03 데이터 불러오기
#
# - 경로 작성
#     - / ~/ ./ ../
# - txt 파일
#     - open
#     - read, readline, write
# - json 파일
#     - json 모듈
#     - dump, load
# - csv 파일
#     - pandas 모듈
#     - read_csv, to_csv
# - xlsx 파일
#     - pnadas 모듈
#     - read_excel, to_excel
# - DataFrame 기본 정보
#     - df.shape
#     - df.columns
#     - df.index
#     - df.dtypes

# %% [markdown]
# ### 04 데이터 분석 스킬 1
#
# - DataFrame과 Series
#     - row와 columns (DataFrame)
#     - row만 존재(Serise)
# - DataFrame의 시퀀스 연산자
#     - df[] => 컬럼
#     - setindex, reset_index
#     - df.loc[] => 인덱스 이름
#     - df.iloc[] => 인덱스 순번
# - 조건 인덱싱
#     - unique, max, min
#     - df[bool 시리즈]
#     - isin, between
#     - ~, &, /
# - 샘플링
#     - sample
#     - nlargest, nsmallest
# - 기본정보 변환
#     - rename
#     - astype
# - 제거
#     - drop
#     - drop_duplicates
#     - dropna
# - 정렬
#     - sort_values
#     - sort_index
#     - rank
# - 일괄 연산 및 처리
#     - 연산자 활용
#     - apply
#         - lambda
#         - datetime64
#             - strftime
#     - fillna
#         - mean

# %% [markdown]
# ### 05 데이터 분석 스킬2
# - 수평 결합(연결)
#     - concat
#     - pathlib, glob
# - 수직 결합(병합)
#     - merge, join
# - 데이터 집계
#     - sum, mean, std, var, value_counts
#     - groupby
# - 테이블 집계
#     - crosstab
#     - pivot_table

# %% [markdown]
# ### 06 데이터 시각화
#
# - matplotlib과 seaborn
#     - plt.show
# - 막대그래프
#     - plt.bar
#     - sns.barplot
#     - plt.barh
# - 선그래프
#     - plt.plot
#     - sns.lineplot
# - 산점도 그래프
#     - plt.scatter
#     - sns.scatterplot
#     - sns.relplot
# - 여러개의 그래프
#     - figure와 ax
#     - subplot
# - 히스토 그램
#     - plt.hist
#     - sns.histplot
# - 히트맵
#     - sns.heatmap
# - 상자그림
#     - 사분위수
#         - df.quartile
#     - plt.boxplot
#     - sns.boxplot
